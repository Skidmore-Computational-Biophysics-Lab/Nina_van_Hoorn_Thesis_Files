# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import matplotlib.ticker as ticker
import decimal as dec

# %% [markdown]
# This notebook was adapted from previous code written in Skdimore's computational biophysics lab

# %% [markdown]
# # Calculated mean and variance

# %%
GLU_pca = pd.read_table ('GLU_mut_project_onto_evecs.dat', sep = '\s+')
WT_pca = pd.read_table ('VCBC_A3F_project_onto_evecs.dat', sep = '\\s+') 
pdb_PCA = pd.read_table ('pdb_project_onto_evecs.dat', sep = '\\s+')

# %%
pdb_PCA
# Out:
#    #Frame   Mode1   Mode2   Mode3   Mode4   Mode5  Mode6  Mode7  Mode8  \
# 0       1  27.137  51.608 -20.138 -14.312 -19.914  2.557 -7.996 -9.435
#
#     Mode9  Mode10
# 0  10.762 -33.338

# %%
GLU_Mean_std_PC1and2 = {"Simulation":["1","2","3","4","5","6","7","8"],
                    'Mean_PC1':[GLU_pca['Mode1'][1:6000:10].mean(),
                    GLU_pca['Mode1'][6001:12000:10].mean(),
                    GLU_pca['Mode1'][12001:18000:10].mean(),
                    GLU_pca['Mode1'][18001:24000:10].mean(),
                    GLU_pca['Mode1'][24001:30000:10].mean(),
                    GLU_pca['Mode1'][30001:36000:10].mean(),
                    GLU_pca['Mode1'][36001:42000:10].mean(),
                    GLU_pca['Mode1'][42001:48000:10].mean()], 
     'Variance_PC1':[GLU_pca['Mode1'][1:6000:10].var(),
                    GLU_pca['Mode1'][6001:12000:10].var(),
                    GLU_pca['Mode1'][12001:18000:10].var(),
                    GLU_pca['Mode1'][18001:24000:10].var(),
                    GLU_pca['Mode1'][24001:30000:10].var(),
                    GLU_pca['Mode1'][30001:36000:10].var(),
                    GLU_pca['Mode1'][36001:42000:10].var(),
                    GLU_pca['Mode1'][42001:48000:10].var()],
     'Mean_PC2': [GLU_pca['Mode2'][1:6000:10].mean(),
                    GLU_pca['Mode2'][6001:12000:10].mean(),
                    GLU_pca['Mode2'][12001:18000:10].mean(),
                    GLU_pca['Mode2'][18001:24000:10].mean(),
                    GLU_pca['Mode2'][24001:30000:10].mean(),
                    GLU_pca['Mode2'][30001:36000:10].mean(),
                    GLU_pca['Mode2'][36001:42000:10].mean(),
                    GLU_pca['Mode2'][42001:48000:10].mean()],
     "Variance_PC2":[GLU_pca['Mode2'][1:6000:10].var(),
                    GLU_pca['Mode2'][6001:12000:10].var(),
                    GLU_pca['Mode2'][12001:18000:10].var(),
                    GLU_pca['Mode2'][18001:24000:10].var(),
                    GLU_pca['Mode2'][24001:30000:10].var(),
                    GLU_pca['Mode2'][30001:36000:10].var(),
                    GLU_pca['Mode2'][36001:42000:10].var(),
                    GLU_pca['Mode2'][42001:48000:10].var()],
     'Mean_PC3': [GLU_pca['Mode3'][1:6000:10].mean(),
                    GLU_pca['Mode3'][6001:12000:10].mean(),
                    GLU_pca['Mode3'][12001:18000:10].mean(),
                    GLU_pca['Mode3'][18001:24000:10].mean(),
                    GLU_pca['Mode3'][24001:30000:10].mean(),
                    GLU_pca['Mode3'][30001:36000:10].mean(),
                    GLU_pca['Mode3'][36001:42000:10].mean(),
                    GLU_pca['Mode3'][42001:48000:10].mean()],
     "Variance_PC3":[GLU_pca['Mode3'][1:6000:10].var(),
                    GLU_pca['Mode3'][6001:12000:10].var(),
                    GLU_pca['Mode3'][12001:18000:10].var(),
                    GLU_pca['Mode3'][18001:24000:10].var(),
                    GLU_pca['Mode3'][24001:30000:10].var(),
                    GLU_pca['Mode3'][30001:36000:10].var(),
                    GLU_pca['Mode3'][36001:42000:10].var(),
                    GLU_pca['Mode3'][42001:48000:10].var()],
     'Mean_PC4': [GLU_pca['Mode4'][1:6000:10].mean(),
                    GLU_pca['Mode4'][6001:12000:10].mean(),
                    GLU_pca['Mode4'][12001:18000:10].mean(),
                    GLU_pca['Mode4'][18001:24000:10].mean(),
                    GLU_pca['Mode4'][24001:30000:10].mean(),
                    GLU_pca['Mode4'][30001:36000:10].mean(),
                    GLU_pca['Mode4'][36001:42000:10].mean(),
                    GLU_pca['Mode4'][42001:48000:10].mean()],
     "Variance_PC4":[GLU_pca['Mode4'][1:6000:10].var(),
                    GLU_pca['Mode4'][6001:12000:10].var(),
                    GLU_pca['Mode4'][12001:18000:10].var(),
                    GLU_pca['Mode4'][18001:24000:10].var(),
                    GLU_pca['Mode4'][24001:30000:10].var(),
                    GLU_pca['Mode4'][30001:36000:10].var(),
                    GLU_pca['Mode4'][36001:42000:10].var(),
                    GLU_pca['Mode4'][42001:48000:10].var()],
            "PDB_PC1":[pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values],
            "PDB_PC2":[pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values],
            "PDB_PC3":[pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values],
            "PDB_PC4":[pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values],}
GLU_Mean_std_PC1and2_df = pd.DataFrame(data = GLU_Mean_std_PC1and2)
GLU_Mean_std_PC1and2_df["Meandiffsqr_PC1"]= (GLU_Mean_std_PC1and2_df["Mean_PC1"]- GLU_Mean_std_PC1and2_df["PDB_PC1"])**2
GLU_Mean_std_PC1and2_df["Meandiffsqr_PC2"]= (GLU_Mean_std_PC1and2_df["Mean_PC2"]- GLU_Mean_std_PC1and2_df["PDB_PC2"])**2
GLU_Mean_std_PC1and2_df["Meandiffsqr_PC3"]= (GLU_Mean_std_PC1and2_df["Mean_PC3"]- GLU_Mean_std_PC1and2_df["PDB_PC3"])**2
GLU_Mean_std_PC1and2_df["Meandiffsqr_PC4"]= (GLU_Mean_std_PC1and2_df["Mean_PC4"]- GLU_Mean_std_PC1and2_df["PDB_PC4"])**2
GLU_Mean_std_PC1and2_df
# Out:
#   Simulation   Mean_PC1  Variance_PC1    Mean_PC2  Variance_PC2   Mean_PC3  \
# 0          1  63.346715    427.719258   20.871447   1505.437088 -18.381920
# 1          2  72.488610    308.832051   56.519642    393.826341 -10.571742
# 2          3  50.604277    751.141817   54.467482    519.720863  -3.889013
# 3          4   9.718460    479.922860   28.264340    143.212815   0.425247
# 4          5  11.146423    255.987254   16.990860    264.640530   3.840122
# 5          6  21.506895    373.922879   50.834098    310.945392  -3.028297
# 6          7  40.801420    241.812146  107.985118    322.532700  11.474375
# 7          8  38.452200    642.559194   98.676777    330.037408  16.592128
#
#    Variance_PC3   Mean_PC4  Variance_PC4   PDB_PC1   PDB_PC2    PDB_PC3  \
# 0    207.811967 -19.812938    119.040286  [27.137]  [51.608]  [-20.138]
# 1    149.102479 -26.358050     47.773282  [27.137]  [51.608]  [-20.138]
# 2    191.955375 -23.543147     47.805429  [27.137]  [51.608]  [-20.138]
# ...

# %%
WT_Mean_std_PC1and2 = {"Simulation":["1","2","3","4","5","6","7","8"],
                    'Mean_PC1':[WT_pca['Mode1'][1:6000:10].mean(),
                    WT_pca['Mode1'][6001:12000:10].mean(),
                    WT_pca['Mode1'][12001:18000:10].mean(),
                    WT_pca['Mode1'][18001:24000:10].mean(),
                    WT_pca['Mode1'][24001:30000:10].mean(),
                    WT_pca['Mode1'][30001:36000:10].mean(),
                    WT_pca['Mode1'][36001:42000:10].mean(),
                    WT_pca['Mode1'][42001:48000:10].mean()], 
     'Variance_PC1':[WT_pca['Mode1'][1:6000:10].var(),
                    WT_pca['Mode1'][6001:12000:10].var(),
                    WT_pca['Mode1'][12001:18000:10].var(),
                    WT_pca['Mode1'][18001:24000:10].var(),
                    WT_pca['Mode1'][24001:30000:10].var(),
                    WT_pca['Mode1'][30001:36000:10].var(),
                    WT_pca['Mode1'][36001:42000:10].var(),
                    WT_pca['Mode1'][42001:48000:10].var()],
     'Mean_PC2': [WT_pca['Mode2'][1:6000:10].mean(),
                    WT_pca['Mode2'][6001:12000:10].mean(),
                    WT_pca['Mode2'][12001:18000:10].mean(),
                    WT_pca['Mode2'][18001:24000:10].mean(),
                    WT_pca['Mode2'][24001:30000:10].mean(),
                    WT_pca['Mode2'][30001:36000:10].mean(),
                    WT_pca['Mode2'][36001:42000:10].mean(),
                    WT_pca['Mode2'][42001:48000:10].mean()],
     "Variance_PC2":[WT_pca['Mode2'][1:6000:10].var(),
                    WT_pca['Mode2'][6001:12000:10].var(),
                    WT_pca['Mode2'][12001:18000:10].var(),
                    WT_pca['Mode2'][18001:24000:10].var(),
                    WT_pca['Mode2'][24001:30000:10].var(),
                    WT_pca['Mode2'][30001:36000:10].var(),
                    WT_pca['Mode2'][36001:42000:10].var(),
                    WT_pca['Mode2'][42001:48000:10].var()],
     'Mean_PC3': [WT_pca['Mode3'][1:6000:10].mean(),
                    WT_pca['Mode3'][6001:12000:10].mean(),
                    WT_pca['Mode3'][12001:18000:10].mean(),
                    WT_pca['Mode3'][18001:24000:10].mean(),
                    WT_pca['Mode3'][24001:30000:10].mean(),
                    WT_pca['Mode3'][30001:36000:10].mean(),
                    WT_pca['Mode3'][36001:42000:10].mean(),
                    WT_pca['Mode3'][42001:48000:10].mean()],
     "Variance_PC3":[WT_pca['Mode3'][1:6000:10].var(),
                    WT_pca['Mode3'][6001:12000:10].var(),
                    WT_pca['Mode3'][12001:18000:10].var(),
                    WT_pca['Mode3'][18001:24000:10].var(),
                    WT_pca['Mode3'][24001:30000:10].var(),
                    WT_pca['Mode3'][30001:36000:10].var(),
                    WT_pca['Mode3'][36001:42000:10].var(),
                    WT_pca['Mode3'][42001:48000:10].var()],
     'Mean_PC4': [WT_pca['Mode4'][1:6000:10].mean(),
                    WT_pca['Mode4'][6001:12000:10].mean(),
                    WT_pca['Mode4'][12001:18000:10].mean(),
                    WT_pca['Mode4'][18001:24000:10].mean(),
                    WT_pca['Mode4'][24001:30000:10].mean(),
                    WT_pca['Mode4'][30001:36000:10].mean(),
                    WT_pca['Mode4'][36001:42000:10].mean(),
                    WT_pca['Mode4'][42001:48000:10].mean()],
     "Variance_PC4":[WT_pca['Mode4'][1:6000:10].var(),
                    WT_pca['Mode4'][6001:12000:10].var(),
                    WT_pca['Mode4'][12001:18000:10].var(),
                    WT_pca['Mode4'][18001:24000:10].var(),
                    WT_pca['Mode4'][24001:30000:10].var(),
                    WT_pca['Mode4'][30001:36000:10].var(),
                    WT_pca['Mode4'][36001:42000:10].var(),
                    WT_pca['Mode4'][42001:48000:10].var()],
            "PDB_PC1":[pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values,
                     pdb_PCA["Mode1"].values],
            "PDB_PC2":[pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values,
                     pdb_PCA["Mode2"].values],
            "PDB_PC3":[pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values,
                     pdb_PCA["Mode3"].values],
            "PDB_PC4":[pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values,
                     pdb_PCA["Mode4"].values],}
WT_Mean_std_PC1and2_df = pd.DataFrame(data = WT_Mean_std_PC1and2)
WT_Mean_std_PC1and2_df["Meandiffsqr_PC1"]= (WT_Mean_std_PC1and2_df["Mean_PC1"]- WT_Mean_std_PC1and2_df["PDB_PC1"])**2
WT_Mean_std_PC1and2_df["Meandiffsqr_PC2"]= (WT_Mean_std_PC1and2_df["Mean_PC2"]- WT_Mean_std_PC1and2_df["PDB_PC2"])**2
WT_Mean_std_PC1and2_df["Meandiffsqr_PC3"]= (WT_Mean_std_PC1and2_df["Mean_PC3"]- WT_Mean_std_PC1and2_df["PDB_PC3"])**2
WT_Mean_std_PC1and2_df["Meandiffsqr_PC4"]= (WT_Mean_std_PC1and2_df["Mean_PC4"]- WT_Mean_std_PC1and2_df["PDB_PC4"])**2
WT_Mean_std_PC1and2_df
# Out:
#   Simulation    Mean_PC1  Variance_PC1    Mean_PC2  Variance_PC2   Mean_PC3  \
# 0          1  -20.220108    594.058793   27.232208    477.042155  18.280875
# 1          2  -11.324725    295.793982   67.364715    164.484862  58.506575
# 2          3  -24.142723   1647.583189   59.995032    646.415360  46.379790
# 3          4   24.567788    525.496686   68.712833    257.397908  11.322693
# 4          5   28.424598    262.843877   59.385385    268.447487 -10.775310
# 5          6   25.520252    413.741936   91.917398   1572.831670   7.630592
# 6          7   92.765205   1462.327322  225.314505   1163.947774  20.012430
# 7          8  159.197462    251.120173  304.636662    298.617663  32.894697
#
#    Variance_PC3    Mean_PC4  Variance_PC4   PDB_PC1   PDB_PC2    PDB_PC3  \
# 0    338.138371   11.624007    189.997180  [27.137]  [51.608]  [-20.138]
# 1    100.058760   22.704305     47.413286  [27.137]  [51.608]  [-20.138]
# ...

# %% [markdown]
# # GLU x WT

# %%
#define our variance data for pc1
Variance_PC1= np.concatenate([GLU_Mean_std_PC1and2_df["Variance_PC1"].values,
                              WT_Mean_std_PC1and2_df["Variance_PC1"].values])
#calculate the variance ratio for real groups VCBC-Cul5/VCBC
varianceratio_pc1_data = np.sum(Variance_PC1[0:8]) / np.sum(Variance_PC1[8:16])

#sample 10000 times and calculate variance ratios
numsample = 10000
varianceratio_pc1_samples = [0]*numsample
varianceratio_pc1_samples_smaller = [0]*numsample
for sample in range(0,len(varianceratio_pc1_samples)):
    random_groups = np.random.permutation(Variance_PC1)
    varianceratio_pc1_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if varianceratio_pc1_samples[sample] <= varianceratio_pc1_data:
        varianceratio_pc1_samples_smaller[sample] = 1
print(np.mean(varianceratio_pc1_samples))
print(np.sum(varianceratio_pc1_samples_smaller))

#calculate p-value
pval_variance_PC1 = (1 + np.sum(varianceratio_pc1_samples_smaller))/(numsample + 1)
print(" p-value variance PC1 = " , pval_variance_PC1)
# Out:
# 1.0701116677955949
# 1615
#  p-value variance PC1 =  0.1615838416158384

# %%
#define our variance data for pc2
Variance_PC2= np.concatenate([GLU_Mean_std_PC1and2_df["Variance_PC2"].values,
                              WT_Mean_std_PC1and2_df["Variance_PC2"].values])
#calculate the variance ratio for real groups VCBC-Cul5/VCBC
varianceratio_pc2_data = np.sum(Variance_PC2[0:8]) / np.sum(Variance_PC2[8:16])

#sample 10000 times and calculate variance ratios
numsample = 10000
varianceratio_pc2_samples = [0]*numsample
varianceratio_pc2_samples_smaller = [0]*numsample
for sample in range(0,len(varianceratio_pc2_samples)):
    random_groups = np.random.permutation(Variance_PC2)
    varianceratio_pc2_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if varianceratio_pc2_samples[sample] <= varianceratio_pc2_data:
        varianceratio_pc2_samples_smaller[sample] = 1
print(np.mean(varianceratio_pc2_samples))
print(np.sum(varianceratio_pc2_samples_smaller))

#calculate p-value
pval_variance_PC2 = (1 + np.sum(varianceratio_pc2_samples_smaller))/(numsample + 1)
print("p-value variance PC2 = " , pval_variance_PC2)
# Out:
# 1.1065235747581412
# 3034
# p-value variance PC2 =  0.30346965303469653

# %%
#define our variance data for pc3
Variance_PC3= np.concatenate([GLU_Mean_std_PC1and2_df["Variance_PC3"].values,
                              WT_Mean_std_PC1and2_df["Variance_PC3"].values])
#calculate the variance ratio for real groups VCBC-Cul5/VCBC
varianceratio_pc3_data = np.sum(Variance_PC3[0:8]) / np.sum(Variance_PC3[8:16])

#sample 10000 times and calculate variance ratios
numsample = 10000
varianceratio_pc3_samples = [0]*numsample
varianceratio_pc3_samples_smaller = [0]*numsample
for sample in range(0,len(varianceratio_pc3_samples)):
    random_groups = np.random.permutation(Variance_PC3)
    varianceratio_pc3_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if varianceratio_pc3_samples[sample] <= varianceratio_pc3_data:
        varianceratio_pc3_samples_smaller[sample] = 1
print(np.mean(varianceratio_pc3_samples))
print(np.sum(varianceratio_pc3_samples_smaller))

#calculate p-value
pval_variance_PC3 = (1 + np.sum(varianceratio_pc3_samples_smaller))/(numsample + 1)
print("p-value variance PC3 = " , pval_variance_PC3)
# Out:
# 1.029579447096087
# 5909
# p-value variance PC3 =  0.5909409059094091

# %%
#define our variance data for pc4
Variance_PC4= np.concatenate([GLU_Mean_std_PC1and2_df["Variance_PC4"].values,
                              WT_Mean_std_PC1and2_df["Variance_PC4"].values])
#calculate the variance ratio for real groups VCBC-Cul5/VCBC
varianceratio_pc4_data = np.sum(Variance_PC4[0:8]) / np.sum(Variance_PC4[8:16])

#sample 10000 times and calculate variance ratios
numsample = 10000
varianceratio_pc4_samples = [0]*numsample
varianceratio_pc4_samples_smaller = [0]*numsample
for sample in range(0,len(varianceratio_pc4_samples)):
    random_groups = np.random.permutation(Variance_PC4)
    varianceratio_pc4_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if varianceratio_pc4_samples[sample] <= varianceratio_pc4_data:
        varianceratio_pc4_samples_smaller[sample] = 1
print(np.mean(varianceratio_pc4_samples))
print(np.sum(varianceratio_pc4_samples_smaller))

#calculate p-value
pval_variance_PC4 = (1 + np.sum(varianceratio_pc4_samples_smaller))/(numsample + 1)
print("p-value variance PC4 = " , pval_variance_PC4)
# Out:
# 1.1497123810458276
# 778
# p-value variance PC4 =  0.07789221077892211

# %%
#define our mean data for pc1
Meandiffsqr_PC1= np.concatenate([GLU_Mean_std_PC1and2_df["Meandiffsqr_PC1"].values,
                              WT_Mean_std_PC1and2_df["Meandiffsqr_PC1"].values])
#calculate the ratio of rmse for real groups VCBC-Cul5/VCBC
rmse1 = np.sqrt(np.mean(Meandiffsqr_PC1[0:8]))
rmse2 = np.sqrt(np.mean(Meandiffsqr_PC1[8:16]))
rmseratio_pc1_data = rmse1 / rmse2

#sample 10000 times and calculate RMSE ratios
numsample = 10000
rmseratio_pc1_samples = [0]*numsample
rmseratio_pc1_samples_smaller = [0]*numsample
for sample in range(0,len(rmseratio_pc1_samples)):
    random_groups = np.random.permutation(Meandiffsqr_PC1)
    rmseratio_pc1_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if rmseratio_pc1_samples[sample] <= rmseratio_pc1_data:
        rmseratio_pc1_samples_smaller[sample] = 1

#calculate p-value
pval_rmse_PC1 = (1 + np.sum(rmseratio_pc1_samples_smaller))/(numsample + 1)
print("p-value rmse PC1 = " , pval_rmse_PC1)
#print(rmseratio_pc1_data)
# Out:
# p-value rmse PC1 =  0.34296570342965704

# %%
#define our mean data for pc2
Meandiffsqr_PC2= np.concatenate([GLU_Mean_std_PC1and2_df["Meandiffsqr_PC2"].values,
                              WT_Mean_std_PC1and2_df["Meandiffsqr_PC2"].values])
#calculate the ratio of rmse for real groups VCBC-Cul5/VCBC
rmse1 = np.sqrt(np.mean(Meandiffsqr_PC2[0:8]))
rmse2 = np.sqrt(np.mean(Meandiffsqr_PC2[8:16]))
rmseratio_pc2_data = rmse1 / rmse2

#sample 10000 times and calculate RMSE ratios
numsample = 10000
rmseratio_pc2_samples = [0]*numsample
rmseratio_pc2_samples_smaller = [0]*numsample
for sample in range(0,len(rmseratio_pc2_samples)):
    random_groups = np.random.permutation(Meandiffsqr_PC2)
    rmseratio_pc2_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if rmseratio_pc2_samples[sample] <= rmseratio_pc2_data:
        rmseratio_pc2_samples_smaller[sample] = 1

#calculate p-value
pval_rmse_PC2 = (1 + np.sum(rmseratio_pc2_samples_smaller))/(numsample + 1)
print("p-value rmse PC2 = " , pval_rmse_PC2)
# Out:
# p-value rmse PC2 =  0.2263773622637736

# %%
#define our mean data for pc3
Meandiffsqr_PC3= np.concatenate([GLU_Mean_std_PC1and2_df["Meandiffsqr_PC3"].values,
                              WT_Mean_std_PC1and2_df["Meandiffsqr_PC3"].values])
#calculate the ratio of rmse for real groups VCBC-Cul5/VCBC
rmse1 = np.sqrt(np.mean(Meandiffsqr_PC3[0:8]))
rmse2 = np.sqrt(np.mean(Meandiffsqr_PC3[8:16]))
rmseratio_pc3_data = rmse1 / rmse2

#sample 10000 times and calculate RMSE ratios
numsample = 10000
rmseratio_pc3_samples = [0]*numsample
rmseratio_pc3_samples_smaller = [0]*numsample
for sample in range(0,len(rmseratio_pc3_samples)):
    random_groups = np.random.permutation(Meandiffsqr_PC3)
    rmseratio_pc3_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if rmseratio_pc3_samples[sample] <= rmseratio_pc3_data:
        rmseratio_pc3_samples_smaller[sample] = 1

#calculate p-value
pval_rmse_PC3 = (1 + np.sum(rmseratio_pc3_samples_smaller))/(numsample + 1)
print("p-value rmse PC3 = " , pval_rmse_PC3)
# Out:
# p-value rmse PC3 =  0.14208579142085792

# %%
#define our mean data for pc4
Meandiffsqr_PC4= np.concatenate([GLU_Mean_std_PC1and2_df["Meandiffsqr_PC4"].values,
                              WT_Mean_std_PC1and2_df["Meandiffsqr_PC4"].values])
#calculate the ratio of rmse for real groups VCBC-Cul5/VCBC
rmse1 = np.sqrt(np.mean(Meandiffsqr_PC4[0:8]))
rmse2 = np.sqrt(np.mean(Meandiffsqr_PC4[8:16]))
rmseratio_pc4_data = rmse1 / rmse2

#sample 10000 times and calculate RMSE ratios
numsample = 10000
rmseratio_pc4_samples = [0]*numsample
rmseratio_pc4_samples_smaller = [0]*numsample
for sample in range(0,len(rmseratio_pc4_samples)):
    random_groups = np.random.permutation(Meandiffsqr_PC4)
    rmseratio_pc4_samples[sample] = np.sum(random_groups[0:8]) / np.sum(random_groups[8:16])
    if rmseratio_pc4_samples[sample] <= rmseratio_pc4_data:
        rmseratio_pc4_samples_smaller[sample] = 1

#calculate p-value
pval_rmse_PC4 = (1 + np.sum(rmseratio_pc4_samples_smaller))/(numsample + 1)
print("p-value rmse PC4 = " , pval_rmse_PC4)
# Out:
# p-value rmse PC4 =  0.18708129187081293
